# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# altair                    5.3.0
# appnope                   0.1.4
# asari                     0.2.0
# asttokens                 2.4.1
# attrs                     23.2.0
# backcall                  0.2.0
# blinker                   1.7.0
# branca                    0.7.2
# cachetools                5.3.3
# certifi                   2024.2.2
# charset-normalizer        3.3.2
# click                     8.1.7
# coloredlogs               15.0.1
# comm                      0.2.2
# debugpy                   1.8.1
# decorator                 5.1.1
# executing                 2.0.1
# flatbuffers               24.3.25
# folium                    0.16.0
# geographiclib             2.0
# geopy                     2.4.1
# gitdb                     4.0.11
# GitPython                 3.1.43
# google-auth               2.29.0
# google-auth-oauthlib      1.2.0
# gspread                   6.1.2
# gspread-dataframe         3.3.1
# humanfriendly             10.0
# idna                      3.7
# importlib_metadata        7.1.0
# importlib_resources       6.4.0
# install                   1.3.5
# ipykernel                 6.29.4
# ipython                   8.12.3
# Janome                    0.4.2
# jedi                      0.19.1
# Jinja2                    3.1.3
# joblib                    1.4.0
# jsonschema                4.21.1
# jsonschema-specifications 2023.12.1
# jupyter_client            8.6.1
# jupyter_core              5.7.2
# markdown-it-py            3.0.0
# MarkupSafe                2.1.5
# matplotlib-inline         0.1.6
# mdurl                     0.1.2
# mpmath                    1.3.0
# nest-asyncio              1.6.0
# numpy                     1.24.4
# oauthlib                  3.2.2
# onnx                      1.16.0
# onnxconverter-common      1.14.0
# onnxruntime               1.16.3
# packaging                 21.3
# pandas                    2.0.3
# parso                     0.8.4
# pexpect                   4.9.0
# pickleshare               0.7.5
# pillow                    10.3.0
# pip                       23.3.1
# pkgutil_resolve_name      1.3.10
# platformdirs              4.2.0
# prompt-toolkit            3.0.43
# protobuf                  3.20.2
# psutil                    5.9.8
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pyarrow                   15.0.2
# pyasn1                    0.6.0
# pyasn1_modules            0.4.0
# pydeck                    0.8.1b0
# Pygments                  2.17.2
# pyocr                     0.8.5
# pyparsing                 3.1.2
# python-dateutil           2.9.0.post0
# python-dotenv             1.0.1
# pytz                      2024.1
# pyzmq                     25.1.2
# referencing               0.34.0
# requests                  2.31.0
# requests-oauthlib         2.0.0
# rich                      13.7.1
# rpds-py                   0.18.0
# rsa                       4.9
# scikit-learn              1.3.2
# scipy                     1.10.1
# setuptools                68.2.2
# six                       1.16.0
# skl2onnx                  1.16.0
# smmap                     5.0.1
# stack-data                0.6.3
# streamlit                 1.33.0
# streamlit_folium          0.20.0
# sympy                     1.12
# tenacity                  8.2.3
# threadpoolctl             3.4.0
# toml                      0.10.2
# toolz                     0.12.1
# tornado                   6.4
# traitlets                 5.14.2
# typing_extensions         4.11.0
# tzdata                    2024.1
# urllib3                   2.2.1
# wcwidth                   0.2.13
# wheel                     0.41.2
# xyzservices               2024.4.0
# zipp                      3.18.1

# %%
# !pip install gspread-dataframe
# !pip install dotenv
# !pip install python-dotenv
# !pip install geopy
# !pip install folium
# !pip install streamlit_folium
# Out:
# Requirement already satisfied: gspread-dataframe in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (3.3.1)
# Requirement already satisfied: gspread>=3.0.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from gspread-dataframe) (6.1.2)
# Requirement already satisfied: pandas>=0.24.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from gspread-dataframe) (2.0.3)
# Requirement already satisfied: six>=1.12.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from gspread-dataframe) (1.16.0)
# Requirement already satisfied: google-auth>=1.12.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from gspread>=3.0.0->gspread-dataframe) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from gspread>=3.0.0->gspread-dataframe) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas>=0.24.0->gspread-dataframe) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas>=0.24.0->gspread-dataframe) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas>=0.24.0->gspread-dataframe) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas>=0.24.0->gspread-dataframe) (1.24.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread>=3.0.0->gspread-dataframe) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.0.0->gspread-dataframe) (2024.2.2)
# Collecting dotenv
#   Using cached dotenv-0.0.5.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [76 lines of output]
#       /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#         error: subprocess-exited-with-error
#
#         × python setup.py egg_info did not run successfully.
#         │ exit code: 1
#         ╰─> [16 lines of output]
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 14, in <module>
#               File "/private/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/pip-wheel-_asf9m6j/distribute_e5baec0d70bf4d9299ba736942e6850d/setuptools/__init__.py", line 2, in <module>
#                 from setuptools.extension import Extension, Library
#               File "/private/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/pip-wheel-_asf9m6j/distribute_e5baec0d70bf4d9299ba736942e6850d/setuptools/extension.py", line 5, in <module>
#                 from setuptools.dist import _get_unpatched
#               File "/private/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/pip-wheel-_asf9m6j/distribute_e5baec0d70bf4d9299ba736942e6850d/setuptools/dist.py", line 7, in <module>
#                 from setuptools.command.install import install
#               File "/private/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/pip-wheel-_asf9m6j/distribute_e5baec0d70bf4d9299ba736942e6850d/setuptools/command/__init__.py", line 8, in <module>
#                 from setuptools.command import install_scripts
#               File "/private/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/pip-wheel-_asf9m6j/distribute_e5baec0d70bf4d9299ba736942e6850d/setuptools/command/install_scripts.py", line 3, in <module>
#                 from pkg_resources import Distribution, PathMetadata, ensure_directory
#               File "/private/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/pip-wheel-_asf9m6j/distribute_e5baec0d70bf4d9299ba736942e6850d/pkg_resources.py", line 1518, in <module>
#                 register_loader_type(importlib_bootstrap.SourceFileLoader, DefaultProvider)
#             AttributeError: module 'importlib._bootstrap' has no attribute 'SourceFileLoader'
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       Traceback (most recent call last):
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/installer.py", line 101, in _fetch_build_egg_no_warn
#           subprocess.check_call(cmd)
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/subprocess.py", line 364, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['/Users/daisuke_sugiura/anaconda3/envs/myenv/bin/python', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/tmpsehml60l', '--quiet', 'distribute']' returned non-zero exit status 1.
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/pip-install-clus4va_/dotenv_6a63700404834a278275a4f4900d7a5a/setup.py", line 13, in <module>
#           setup(name='dotenv',
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/__init__.py", line 102, in setup
#           _install_setup_requires(attrs)
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/__init__.py", line 75, in _install_setup_requires
#           _fetch_build_eggs(dist)
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/__init__.py", line 80, in _fetch_build_eggs
#           dist.fetch_build_eggs(dist.setup_requires)
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/dist.py", line 662, in fetch_build_eggs
#           return _fetch_build_eggs(self, requires)
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/installer.py", line 38, in _fetch_build_eggs
#           resolved_dists = pkg_resources.working_set.resolve(
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/pkg_resources/__init__.py", line 829, in resolve
#           dist = self._resolve_dist(
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/pkg_resources/__init__.py", line 865, in _resolve_dist
#           dist = best[req.key] = env.best_match(
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/pkg_resources/__init__.py", line 1135, in best_match
#           return self.obtain(req, installer)
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/pkg_resources/__init__.py", line 1147, in obtain
#           return installer(requirement)
#         File "/Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages/setuptools/installer.py", line 103, in _fetch_build_egg_no_warn
#           raise DistutilsError(str(e)) from e
#       distutils.errors.DistutilsError: Command '['/Users/daisuke_sugiura/anaconda3/envs/myenv/bin/python', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/var/folders/m7/jh4vmjk117q7rts48yr56knr0000gn/T/tmpsehml60l', '--quiet', 'distribute']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: python-dotenv in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: geopy in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from geopy) (2.0)
# Requirement already satisfied: folium in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium) (1.24.4)
# Requirement already satisfied: requests in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium) (2024.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium) (2024.2.2)
# Requirement already satisfied: streamlit_folium in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (0.20.0)
# Requirement already satisfied: streamlit>=1.13.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit_folium) (1.33.0)
# Requirement already satisfied: folium!=0.15.0,>=0.13 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit_folium) (0.16.0)
# Requirement already satisfied: jinja2 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit_folium) (3.1.3)
# Requirement already satisfied: branca in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit_folium) (0.7.2)
# Requirement already satisfied: numpy in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium!=0.15.0,>=0.13->streamlit_folium) (1.24.4)
# Requirement already satisfied: requests in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium!=0.15.0,>=0.13->streamlit_folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from folium!=0.15.0,>=0.13->streamlit_folium) (2024.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jinja2->streamlit_folium) (2.1.5)
# Requirement already satisfied: altair<6,>=4.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (8.1.7)
# Requirement already satisfied: packaging<25,>=16.8 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (21.3)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (3.20.2)
# Requirement already satisfied: pyarrow>=7.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (15.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from streamlit>=1.13.0->streamlit_folium) (6.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (4.21.1)
# Requirement already satisfied: toolz in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit_folium) (4.0.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from packaging<25,>=16.8->streamlit>=1.13.0->streamlit_folium) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from requests->folium!=0.15.0,>=0.13->streamlit_folium) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit_folium) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit_folium) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit_folium) (5.0.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (23.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (6.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.13.0->streamlit_folium) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit_folium) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/daisuke_sugiura/anaconda3/envs/myenv/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit_folium) (3.18.1)

# %%
import os
import streamlit as st
import pandas as pd
import numpy as np
import gspread
from google.oauth2.service_account import Credentials
from gspread_dataframe import set_with_dataframe
from dotenv import load_dotenv
from geopy.geocoders import Nominatim
import folium
from streamlit_folium import folium_static

# %%
# 環境変数の読み込み
load_dotenv()

# 環境変数から認証情報を取得
# Python コード
SPREADSHEET_ID = os.getenv("SPREADSHEET_ID")
PRIVATE_KEY_PATH = os.getenv("PRIVATE_KEY_PATH")
SP_SHEET = 'シート1'  # シート名

# %%
# セッション状態の初期化
if 'show_all' not in st.session_state:
    st.session_state['show_all'] = False  # 初期状態は地図上の物件のみを表示

# 地図上以外の物件も表示するボタンの状態を切り替える関数
def toggle_show_all():
    st.session_state['show_all'] = not st.session_state['show_all']

# %%
# スプレッドシートからデータを読み込む関数
def load_data_from_spreadsheet():
    # googleスプレッドシートの認証 jsonファイル読み込み(key値はGCPから取得)
    SP_CREDENTIAL_FILE = PRIVATE_KEY_PATH

    scopes = [
        'https://www.googleapis.com/auth/spreadsheets',
        'https://www.googleapis.com/auth/drive'
    ]

    credentials = Credentials.from_service_account_file(
        SP_CREDENTIAL_FILE,
        scopes=scopes
    )
    gc = gspread.authorize(credentials)

    SP_SHEET_KEY = SPREADSHEET_ID # d/〇〇/edit の〇〇部分。
    sh = gc.open_by_key(SP_SHEET_KEY)
        # 不動産データの取得
    worksheet = sh.worksheet(SP_SHEET) # シートのデータ取得
    pre_data  = worksheet.get_all_values()
    col_name = pre_data[0][:]
    df = pd.DataFrame(pre_data[1:], columns=col_name) # 一段目をカラム、以下データフレームで取得

    return df

# %%
# データフレームの前処理を行う関数
def preprocess_dataframe(df):
    # '家賃' 列を浮動小数点数に変換し、NaN値を取り除く
    df['家賃'] = pd.to_numeric(df['家賃'], errors='coerce')
    df = df.dropna(subset=['家賃'])
    return df

# %%
def make_clickable(url, name):
    return f'<a target="_blank" href="{url}">{name}</a>'

# %%
# 地図を作成し、マーカーを追加する関数
def create_map(filtered_df):
    # 地図の初期設定
    map_center = [filtered_df['latitude'].mean(), filtered_df['longitude'].mean()]
    m = folium.Map(location=map_center, zoom_start=12)

    # マーカーを追加
    for idx, row in filtered_df.iterrows():
        if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
            # ポップアップに表示するHTMLコンテンツを作成
            popup_html = f"""
            <b>名称:</b> {row['名称']}<br>
            <b>アドレス:</b> {row['アドレス']}<br>
            <b>家賃:</b> {row['家賃']}万円<br>
            <b>間取り:</b> {row['間取り']}<br>
            <a href="{row['物件詳細URL']}" target="_blank">物件詳細</a>
            """
            # HTMLをポップアップに設定
            popup = folium.Popup(popup_html, max_width=400)
            folium.Marker(
                [row['latitude'], row['longitude']],
                popup=popup
            ).add_to(m)

    return m

# %%
# 検索結果を表示する関数
def display_search_results(filtered_df):
    # 物件番号を含む新しい列を作成
    filtered_df['物件番号'] = range(1, len(filtered_df) + 1)
    filtered_df['物件詳細URL'] = filtered_df['物件詳細URL'].apply(lambda x: make_clickable(x, "リンク"))
    display_columns = ['物件番号', '名称', 'アドレス', '階数', '家賃', '間取り', '物件詳細URL']
    filtered_df_display = filtered_df[display_columns]
    st.markdown(filtered_df_display.to_html(escape=False, index=False), unsafe_allow_html=True)

# %%
import os

# 環境変数 PRIVATE_KEY_PATH をチェック
sp_credential_file = os.getenv('PRIVATE_KEY_PATH')
if sp_credential_file is None:
    raise ValueError("PRIVATE_KEY_PATH 環境変数が設定されていません。")
elif not os.path.exists(sp_credential_file):
    raise FileNotFoundError(f"指定されたパス {sp_credential_file} が存在しません。")

print("環境変数 PRIVATE_KEY_PATH は正しく設定されています:", sp_credential_file)
# Out:
# 環境変数 PRIVATE_KEY_PATH は正しく設定されています: /Users/daisuke_sugiura/Tech0_step3-1/app/step3-1-424502-efd3137e1c69.json

# %%
import os

# 環境変数の読み込みを確認
print("SPREADSHEET_ID:", os.getenv("SPREADSHEET_ID"))
print("PRIVATE_KEY_PATH:", os.getenv("PRIVATE_KEY_PATH"))
# Out:
# SPREADSHEET_ID: 1GmiycEIDELnEm3-WnHhSbxSVaLcahJ-BKCuZvgd3T88
# PRIVATE_KEY_PATH: /Users/daisuke_sugiura/Tech0_step3-1/app/step3-1-424502-efd3137e1c69.json

# %%
def list_all_worksheets():
    SP_CREDENTIAL_FILE = PRIVATE_KEY_PATH
    scopes = [
        'https://www.googleapis.com/auth/spreadsheets',
        'https://www.googleapis.com/auth/drive'
    ]

    credentials = Credentials.from_service_account_file(
        SP_CREDENTIAL_FILE,
        scopes=scopes
    )
    gc = gspread.authorize(credentials)

    SP_SHEET_KEY = SPREADSHEET_ID
    sh = gc.open_by_key(SP_SHEET_KEY)
    
    # 全シートの名前をリストとして取得
    worksheet_list = sh.worksheets()
    return [ws.title for ws in worksheet_list]

# 全シート名を表示
print(list_all_worksheets())
# Out:
# ['シート1']

# %%
# メインのアプリケーション
def main():
    df = load_data_from_spreadsheet()
    df = preprocess_dataframe(df)

    # StreamlitのUI要素（スライダー、ボタンなど）の各表示設定
    st.title('賃貸物件情報の可視化')

    # エリアと家賃フィルタバーを1:2の割合で分割
    col1, col2 = st.columns([1, 2])

    with col1:
        # エリア選択
        area = st.radio('■ エリア選択', df['区'].unique())


    with col2:
        # 家賃範囲選択のスライダーをfloat型で設定し、小数点第一位まで表示
        price_min, price_max = st.slider(
            '■ 家賃範囲 (万円)', 
            min_value=float(1), 
            max_value=float(df['家賃'].max()),
            value=(float(df['家賃'].min()), float(df['家賃'].max())),
            step=0.1,  # ステップサイズを0.1に設定
            format='%.1f'
        )

    with col2:
    # 間取り選択のデフォルト値をすべてに設定
        type_options = st.multiselect('■ 間取り選択', df['間取り'].unique(), default=df['間取り'].unique())


    # フィルタリング/ フィルタリングされたデータフレームの件数を取得
    filtered_df = df[(df['区'].isin([area])) & (df['間取り'].isin(type_options))]
    filtered_df = filtered_df[(filtered_df['家賃'] >= price_min) & (filtered_df['家賃'] <= price_max)]
    filtered_count = len(filtered_df)

    # 'latitude' と 'longitude' 列を数値型に変換し、NaN値を含む行を削除
    filtered_df['latitude'] = pd.to_numeric(filtered_df['latitude'], errors='coerce')
    filtered_df['longitude'] = pd.to_numeric(filtered_df['longitude'], errors='coerce')
    filtered_df2 = filtered_df.dropna(subset=['latitude', 'longitude'])


    # 検索ボタン / # フィルタリングされたデータフレームの件数を表示
    col2_1, col2_2 = st.columns([1, 2])

    with col2_2:
        st.write(f"物件検索数: {filtered_count}件 / 全{len(df)}件")

    # 検索ボタン
    if col2_1.button('検索＆更新', key='search_button'):
        # 検索ボタンが押された場合、セッションステートに結果を保存
        st.session_state['filtered_df'] = filtered_df
        st.session_state['filtered_df2'] = filtered_df2
        st.session_state['search_clicked'] = True

    # Streamlitに地図を表示
    if st.session_state.get('search_clicked', False):
        m = create_map(st.session_state.get('filtered_df2', filtered_df2))
        folium_static(m)

    # 地図の下にラジオボタンを配置し、選択したオプションに応じて表示を切り替える
    show_all_option = st.radio(
        "表示オプションを選択してください:",
        ('地図上の検索物件のみ', 'すべての検索物件'),
        index=0 if not st.session_state.get('show_all', False) else 1,
        key='show_all_option'
    )

    # ラジオボタンの選択に応じてセッションステートを更新
    st.session_state['show_all'] = (show_all_option == 'すべての検索物件')

    # 検索結果の表示
    if st.session_state.get('search_clicked', False):
        if st.session_state['show_all']:
            display_search_results(st.session_state.get('filtered_df', filtered_df))  # 全データ
        else:
            display_search_results(st.session_state.get('filtered_df2', filtered_df2))  # 地図上の物件のみ


# アプリケーションの実行
if __name__ == "__main__":
    if 'search_clicked' not in st.session_state:
        st.session_state['search_clicked'] = False
    if 'show_all' not in st.session_state:
        st.session_state['show_all'] = False
    main()
